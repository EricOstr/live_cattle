# %% [markdown]
# # Macro Indicators

# %%
import sys
sys.path.append('../')

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import src

import warnings
warnings.filterwarnings('ignore')

# %%
gdp_qrt = src.get_us_gdp_qrt_series()

fig, ax = plt.subplots()
sns.lineplot(data=gdp_qrt, ax=ax)

for i, change in enumerate(gdp_qrt.pct_change()):
    if change < 0:
        ax.axvspan(gdp_qrt.index[i-1], gdp_qrt.index[i], color='grey', alpha=0.2)

ax.set_title('US GDP Quarterly Series')
# Out:
# Text(0.5, 1.0, 'US GDP Quarterly Series')

# %%
sp500 = src.get_sp500_historical_series()

sp500_adj = src.adjust_series_cpi(sp500)

sp500_adj.plot()
# Out:
# <AxesSubplot:>
